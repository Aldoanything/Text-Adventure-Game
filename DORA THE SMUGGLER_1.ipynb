# %% [markdown]
# # DORA THE EXPLORER
#
# Dora owes the Mexican Drug Cartel a huge amount of money and needs your help to repay it. But the question is, where would you get the money? The game features characters from Dora the Explorer like Map, Backpack, and Swiper. The objective of the game is to be able to capture a Baby Winky and to successfully sell it at the US Black Market.
#
# Note:
# 1. For intro scene, pressing enter is equivalent to entering yes
#
# Reference:
#
# Chialtas, G., & Jacobsen, A. (2010, November 17). Dora the Explorer: Baby Winky Comes Home (No. 6.4) [Review of Dora the Explorer: Baby Winky Comes Home]. Nickelodeon.

# %%
# Import random package
import random

#Constructing INTRO scene 
def intro() :
    #START SCREEN
    input(prompt = """ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
           ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠸⡄⢸⠀⣰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣶⣦⣄⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⣀⣀⣙⣼⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣤⣀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⢠⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣦⡀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⢀⣴⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣦⡀⠀⠀
⠀⠀⠀⠀⠀⢠⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣎⠻⣿⣿⣿⡿⠿⠿⢿⡿⣿⣿⣿⣿⣿⣿⣄⠀
⠀⠀⠀⠀⣰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⢻⣿⣿⣿⣿⣿⣿⠿⠛⠋⠉⠀⢉⣤⣖⡦⣄⠀⠈⢿⣿⣿⣿⣿⣿⣿⣿⣷
⠀⠀⠀⣰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠘⣿⠿⠛⠉⠁⠀⠀⠀⠀⠀⢠⣿⣿⣛⣿⡎⣷⠀⠘⣿⣿⣿⣿⣿⣿⣿⡟
⠀⠀⢰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠿⠛⣡⣤⣤⡤⣀⠀⠀⠀⠀⠀⠀⢸⢻⣿⣿⣿⠷⠞⠀⠀⢹⣿⣿⣿⣿⣿⡟⠀
⠀⢀⣿⣿⣿⣿⣿⣿⣿⣿⣿⠛⠁⠀⡜⣾⣿⣏⣿⣯⢳⠀⠀⠀⠀⠀⠀⠉⠉⠁⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⠟⠀⠀
⠀⣸⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⠀⢧⠻⣿⣿⡿⠿⠚⠀⠀⠀⠀⣠⠞⠀⠀⠀⠀⠀⠀⠀⢀⣾⣿⣿⣿⠋⠀⠀⠀
⢠⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⠀⠀⠀⠈⠉⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⠆⠀⠀⠀⠀⢀⣼⣿⣿⠟⠁⠀⠀⠀⠀
⠘⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⠒⠒⠒⠒⡋⠀⠀⠀⠀⢀⣴⣿⡿⠛⠁⠀⠀⠀⠀⠀⠀
⠀⠀⠉⠻⢿⣿⣿⣿⣿⣿⣿⣿⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠁⠀⢀⣠⣴⠿⠛⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠈⠉⠻⠿⣿⣿⣿⣿⣿⣷⣦⣤⣀⣀⣀⣀⣀⣀⣀⡠⠴⠖⢺⣿⡻⠶⣤⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠉⢉⣩⡿⢛⣩⣿⡛⠙⠻⣕⠒⣒⠾⠽⠋⠳⣄⠙⣌⠙⢦⡀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣼⣱⠿⣿⠋⠀⠈⢳⡀⠘⡆⠀⢀⣀⣄⣀⣈⣦⠘⡄⠀⠙⣆⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣏⣿⣿⡇⠀⠀⠀⠀⢳⡀⢹⣴⡿⢷⣿⣇⠀⠈⢻⣧⡴⠶⢾⡇⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⣹⡏⠸⡇⠀⠀⠀⣀⣠⠵⠋⠁⠀⠀⠘⣟⠖⠉⠉⠀⠀⠀⠈⡇⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⣿⠁⠀⢧⣠⡔⠋⠉⠁⠀⠀⠀⠀⠀⡼⠁⠀⠀⠀⠀⠀⠀⣠⠇⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⠀⠀⠘⣷⠳⣄⠀⠀⠀⠀⠀⣠⠞⠛⠉⠉⠉⠓⠒⠒⢿⠁⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣟⣦⣀⣰⣿⣀⠈⠓⠢⠤⠔⠚⠁⣀⣀⣀⣤⣤⣒⣲⠿⣿⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⠿⠿⠿⢾⠉⠉⠒⠒⠒⠒⠊⠉⠁⠀⠀⠀⠀⠀⠀⢀⡟⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⠃⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡾⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⠀⣠⠖⠋⠀⠀⠀⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣤⣀⣀⡀⠀⠀⠀⣀⣷⠦⠤⠤⠤⣤⠞⠃⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⡇⠈⠉⠉⠉⠉⠹⣆⣄⠀⠀⢠⠏⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢧⠀⠀⠀⠀⠀⠀⢠⢿⠲⢤⣯⣀⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠳⣄⠀⠀⠀⠀⣼⡏⠀⠀⡇⠀⠘⣽⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢹⠒⣤⣞⠏⠀⠀⣠⠃⠀⠀⣿⡇⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡟⠀⠉⠀⠉⢳⣾⠕⡻⠀⠀⣿⠃⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⠋⠓⠒⠤⢔⡺⢿⣽⡮⠃⡸⡞⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣏⡀⠀⠀⠀⠘⣆⡠⠿⢤⣔⡽⠁⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠳⠯⣗⣲⣤⠤⠤⠤⠤⣴⡿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡀⡀⠈⠉⠉⠉⠉⠁
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
 ####      ####    #####      ##              ######   ##  ##   ######  
 ## ##    ##  ##   ##  ##    ####               ##     ##  ##   ##      
 ##  ##   ##  ##   ##  ##   ##  ##              ##     ##  ##   ##      
 ##  ##   ##  ##   #####    ######              ##     ######   ####    
 ##  ##   ##  ##   ####     ##  ##              ##     ##  ##   ##      
 ## ##    ##  ##   ## ##    ##  ##              ##     ##  ##   ##      
 ####      ####    ##  ##   ##  ##              ##     ##  ##   ######  
                                                                        
  ####    ##   ##  ##  ##    ####     ####    ##       ######   #####   
 ##  ##   ### ###  ##  ##   ##  ##   ##  ##   ##       ##       ##  ##  
 ##       #######  ##  ##   ##       ##       ##       ##       ##  ##  
  ####    ## # ##  ##  ##   ## ###   ## ###   ##       ####     #####   
     ##   ##   ##  ##  ##   ##  ##   ##  ##   ##       ##       ####    
 ##  ##   ##   ##  ##  ##   ##  ##   ##  ##   ##       ##       ## ##   
  ####    ##   ##   ####     ####     ####    ######   ######   ##  ##  
                                                                        
   
PRESS ENTER TO START""")
    
    
    #ENTER YOUR NAME SCENE 
    player_name = input(prompt = """
    DORA: Hola! Soy Dora!
    BOOTS: And I'm Boots!
    DORA: What's your name?
    PLAYER: Hi! My name is """).upper()
    
    #HUG SCENE
    hug = input(prompt = f"""
    DORA: Nice to meet you, {player_name}! Do you want some hug?
    PLAYER(Yes/No): """).lower().strip()

    if hug in "yes" :
        print(f"""
    DORA: \U0001F917""")
    
    
    elif hug in "no" :
        print("""
    DORA: Aww, that's sad!
    BOOTS: Me and Dora love hugs!""")
    
    else :
        print("""
    DORA: Aww, we did not understand what you said. But anyway, here is a 
            \U0001F917""")
        
    #THE PROBLEM
    helpdora = input(prompt = f"""
    BOOTS: The reason why Dora wants a hug is because she has a problem.
    DORA: Sí, I have a financial problem. I owe the Mexican cartel 500,000 usd.
            Will you help me?
    PLAYER (Yes/No): """).lower().strip()
    
    #If player says yes, the game will proceed to STAGE 1.
    if helpdora in "yes" :
        print("""
    BOOTS: YIPEE! We asked Diego for help and he said if we can capture a 
            Baby Winky, we could sell it in 
            the US Black Market.""")
        input(prompt = """PRESS ENTER TO CONTINUE!""")
        stage1()
    
    
    #If player says no, prompt will ask to end game or restart
    elif helpdora in "no" :
        print(f"""
    DORA: Aww that is sad. I thougt you were a nice person, {player_name}! 
            Goodbye!""")
        reset = input(prompt = """
    Do you want to restart the game? (Yes/No)""").lower().strip()
    
    #RESET/QUIT SYNTAX
        #If reset = yes, game will restart
        if reset in "yes" :
            intro()
        #If reset = no, game will end
        elif reset in "no" :
            fail()
        #If reset = invalid, game will end
        else :
            print("""
    Invalid input!""")
            fail()
    
    else :
        print("""
    Invalid input!""")
        reset = input(prompt = """
    Do you want to restart the game? (Yes/No)""").lower().strip()
    
   #RESET/QUIT SYNTAX
        #If reset = yes, game will restart
        if reset in "yes" :
            intro()
        #If reset = no, game will end
        elif reset in "no" :
            fail()
        #If reset = invalid, game will end
        else :
            print("""
    Invalid input!""")
            fail()


            
# STAGE 1: WHERE DO WE GO?
def stage1() :
    print("""

 ## ##   #### ##    ##      ## ##   ### ###              ##    
##   ##  # ## ##     ##    ##   ##   ##  ##             ###    
####       ##      ## ##   ##        ##                  ##    
 #####     ##      ##  ##  ##  ###   ## ##               ##    
    ###    ##      ## ###  ##   ##   ##                  ##    
##   ##    ##      ##  ##  ##   ##   ##  ##              ##    
 ## ##    ####    ###  ##   ## ##   ### ###             ####                                                                                                                 
""")
    
    input(prompt = """PRESS ENTER TO CONTINUE!""")
    
    whotoask = ['Backpack', 'Map', 'Boots']         

    print("""
    DORA: But first, we should know where we could capture a Baby Winky and
            how to get to the US Black Market. Who do we ask for help if we
            don't know which way to go?""")
    
    # For addtional space
    print()
    
    # For loop to show list of choices
    for items in whotoask :
        print (items)
    
    #WHILE LOOP for answering which item to use for directions
    while True:
        where_to_go = input(prompt = """
    PLAYER: Let's ask (Backpack / Map / Boots)""").capitalize().strip()
            
        
        #If player answered "backpack"
        if where_to_go in whotoask[0] :
            print("""
    You followed Backpack's directions and ended up going backwards!""")
            stage1_fail = input(prompt = """
    ENTER:
        1 to RESTART STAGE 1
        2 to QUIT GAME""").strip()
            
            if stage1_fail == "1" :
                stage1()
                break
            elif stage1_fail == "2":
                fail()
                break
            else :
                print("Invalid input! Restarting game!")
                intro()
                break

        
        #If player answered "map"
        elif where_to_go in whotoask[1] :
            print("""
    DORA: You're right!
    MAP: I'm the map! I'm the map! I'm the MAAAAP!
            I know where you can capture a Baby Winky and how to get to
            the US Black Market. First you will have to go the Highest Mountain
            where a lot of Baby Winkies reside. Then you will have to go to thru
            the US Boarder. After that, you will have to take a car going to 
            the US Black Market.""")
        
            #WHILE LOOP to answer which place to go
            while True :
                place = input(prompt = """
    DORA: So where should we go first?
            
        Type:
            1 for Highest Mountain
            2 for US Boarder
            3 for US Black Market
    
    PLAYER: Let's go to """).strip()
                
                try :
                    place = int(place)
                except :
                    input(prompt = "Kindly select 1, 2, or 3. Press ENTER to try again!")
                
                if place == 1 :
                    print("""
    DORA: Alright! Let's go to the Highest Mountain!""")
                    input(prompt = """PRESS ENTER TO CONTINUE!""")
                    stage2()
                    break
                
                else :
                    print("""
    DORA: I don think that's the right place.""")
            break
        
        
        #If player answered "boots"
        elif where_to_go in whotoask[2]:
            print("""
    You followed Boots' directions and ended up in a jungle were vicious beasts
    ate you!""")
            stage1_fail = input(prompt = """
    ENTER:
        1 to RESTART STAGE 1
        2 to QUIT GAME""").strip()
            
            if stage1_fail == "1" :
                stage1()
                break
            elif stage1_fail == "2":
                fail()
                break
            else :
                print("Invalid input! Restarting game!")
                intro()
                break
        
        else :
            input(prompt = "Invalid input! Check your spelling. PRESS ENTER:")
    
        
# STAGE 2: Capturing a Baby Winky
def stage2() :
    
    # randomizing number for result of trying to catch baby winky
    catch_chance = random.randint(1,10)
    
    # list for chances of tools
    # Pistol has 20% chance of success
    pistol_chance = [1, 2]
    # Bet has 80% fnce of success
    net_chance = [3, 4, 5, 6, 7, 8, 9, 10]
    
    print("""
    
 ## ##   #### ##    ##      ## ##   ### ###           ## ##    
##   ##  # ## ##     ##    ##   ##   ##  ##           ##  ##   
####       ##      ## ##   ##        ##                   ##   
 #####     ##      ##  ##  ##  ###   ## ##               ##    
    ###    ##      ## ###  ##   ##   ##                 ##     
##   ##    ##      ##  ##  ##   ##   ##  ##            #   ##  
 ## ##    ####    ###  ##   ## ##   ### ###           ######                                             
    """)
    
    input(prompt = """PRESS ENTER TO CONTINUE!""")
    
    print("""
    DORA: That was a long viaje!
    BOOT: Yes! It was. Oh look, there is a Baby Winky""")
    
    input(prompt = """PRESS ENTER TO CONTINUE!""")
    
    # WHILE LOOP for cathcing baby winky
    while True :
        catchtool = input(prompt = """
    DORA: What item should we use to catch the Baby Winky?
        Type: 
            1 for Pistol
            2 for Net
            3 for Hands
    
    PLAYER: """)
        
        try:
            catchtool = int(catchtool)
        except:
            input(prompt = "Kindly select 1, 2, or 3. Press ENTER to try again!")
            continue
        
        #IF Statement for using PISTOL
        if catchtool == 1 :
            if catch_chance in pistol_chance :
                print("""
    BOOTS: It worked! Pointing a gun at the Baby Winky made it start to follow
        your orders. Good job!
    
    DORA: Good job! Let's now head to the US!""")
            
                input(prompt = """PRESS ENTER TO CONTINUE!""")
                stage3()
                
                break
            
            else :
                print("""
    BOOTS: NOOOOO! YOU KILLED THE BABY WINKY!""")
                
                stage2_fail = input(prompt = """
    ENTER:
        1 to RESTART STAGE 2
        2 to QUIT GAME
        """)
                if stage2_fail == "1" :
                    stage2()
                    break
                elif stage2_fail == "2":
                    fail()
                    break
                else :
                    print("Invalid input! Restarting game!")
                    intro()
                    break
                    
        #ELIF Statement for using NET
        elif catchtool == 2 :
            if catch_chance  in net_chance :
                print("""
    BOOTS: It worked! The Baby Winky got trapped inside the net!
    
    DORA: Good job! Let's now head to the US!""")
                
                input(prompt = """PRESS ENTER TO CONTINUE!""")
                stage3()
                
                break
            
            else :
                print("""
    BOOTS: You threw the net so short it didn't reach the Baby Winky. We missed
        our chance.""")
                
                stage2_fail = input(prompt = """
    ENTER:
        1 to RESTART STAGE 2
        2 to QUIT GAME
        """)
                if stage2_fail == "1" :
                    stage2()
                    break
                elif stage2_fail == "2":
                    fail()
                    break
                else :
                    print("Invalid input! Restarting game!")
                    intro()
                    break
        
        #ELIF Statement for using HANDS
        elif catchtool == 3 :
            print("""
    You died! You tried to catch the Baby Winky using your hands and it ate you""")
            
            stage2_fail = input(prompt = """
    ENTER:
        1 to RESTART STAGE 2
        2 to QUIT GAME
        """)
            if stage2_fail == "1" :
                stage2()
                break
            elif stage2_fail == "2":
                fail()
                break
            else :
                print("Invalid input! Restarting game!")
                intro()
                break
        
        #ELSE statement if number is not 1 - 3
        else :
            print("""
    DORA: I think we do not have that tool. Try again!""")

# STAGE 3: SWIPER SCENE AND CROSSING THE US BOARDER
def stage3() :
    # randomizing number for result of crossing boarder
    usboarder_chance = random.randint(1,10)
    
    # list for chances of crossing us boarder
    # 30% Chance for Riding a boat
    boat = [1, 2, 3]
    # 60% Chance for Bribing
    bribe = [4, 5, 6, 7, 8, 9]
    # 10% Chance for running
    run = [10]
    
    print("""

 ## ##   #### ##    ##      ## ##   ### ###            ## ##   
##   ##  # ## ##     ##    ##   ##   ##  ##           ##   ##  
####       ##      ## ##   ##        ##                    ##  
 #####     ##      ##  ##  ##  ###   ## ##               ###   
    ###    ##      ## ###  ##   ##   ##                    ##  
##   ##    ##      ##  ##  ##   ##   ##  ##           ##   ##  
 ## ##    ####    ###  ##   ## ##   ### ###            ## ##   
                                                               
    """)
    
    input(prompt = """PRESS ENTER TO CONTINUE!""")
    
    print("""
On the way to the US Boarder, Swiper came out of nowhere...

    DORA: Oh no! Swiper is here to try to steal Baby Winky.
    BOOTS: What should we tell him to stop?""")
    
    #Swiper trying to steal Baby Winky
    # WHILE LOOP for fill SWIPER THE FOX scene
    while True :
        stopswiper = input(prompt = """
FILL IN THE BLANK: Swiper no _________!
(Hint: You do this with your credit card.)

    SWIPER NO """).lower().strip()
        
        # IF STATEMENT for right answer
        if stopswiper == "swiping" :
            print("""
    DORA: SWIPER NO SWIPING!
    BOOTS: SWIPER NO SWIPNIG!
    
    SWIPER: OH MEN!""")
            input(prompt = """PRESS ENTER TO CONTINUE!""")
            print("""
    DORA: Thank you for stopping Swiper from stealing Baby Winky.
    BOOTS: Yeah! Good job!""")
            input(prompt = """PRESS ENTER TO CONTINUE!""")
            print("""
You have safely reached the US Boarder.""")
            break
        
        # ELSE STATEMENT for wrong answer
        else :
            print("""
    DORA: No! That's not the right word. It should be SWIPING.""")
                
    # WHILE LOOP for CROSSING THE US BOARDER
    while True :
        usboarder = input(prompt = """
    DORA: How should we cross the US Boarder?  
            ENTER: 
            1 to Ride a boat
            2 to Bribe the boarder officer
            3 to Run as fast as you can
    
    PLAYER: """)
        
        # TRY/EXCEPT to limit answers to integers
        try:
            usboarder = int(usboarder)
        
        except:
            input(prompt = "Kindly select 1, 2, or 3. Press ENTER to try again!")
            continue
        
        # IF statement for USING A BOAT
        if usboarder == 1 :
            # IF statement if randomized number is in boat list
            if usboarder_chance in boat :
                print("""
You have SUCCESSFULLY crossed the US boarder.
    
    DORA: Good job! Let's now head to the US Black Market!""")
                input(prompt = """PRESS ENTER TO CONTINUE!""")
                stage4()
                break
            
            # ELSE statement if randomized number is not in boat list
            else :
                print("""
You died! The current was too strong that it destroyed the boat.""")
                
                # Quit or Reset Syntax
                stage3_2_fail = input(prompt = """
    ENTER:
        1 to RESTART STAGE 3
        2 to QUIT GAME
        """)
                if stage3_2_fail == "1" :
                    stage3()
                    break
                elif stage3_2_fail == "2":
                    fail()
                    break
                else :
                    print("Invalid input! Restarting game!")
                    intro()
                    break
        
        # ELIF statement for BRIBING THE OFFICER
        elif usboarder == 2 :
            # IF statement if randomized number is in bribe list
            if usboarder_chance in bribe :
                print("""
You have SUCCESSFULLY crossed the US boarder.
    
    DORA: Good job! Let's now head to the US Black Market!""")
                input(prompt = """PRESS ENTER TO CONTINUE!""")
                stage4()
                break
            
            # ELSE statement if randomized number is not in bribe list
            else :
                print("""
You died! The officer that you tried to bribe was a clean cop and shot you
instead!""")
                
                # Quit or Reset Syntax
                stage3_2_fail = input(prompt = """
    ENTER:
        1 to RESTART STAGE 3
        2 to QUIT GAME
        """)
                if stage3_2_fail == "1" :
                    stage3()
                    break
                elif stage3_2_fail == "2":
                    fail()
                    break
                else :
                    print("Invalid input! Restarting game!")
                    intro()
                    break
        
        # ELIF STATEMENT for RUNNING
        elif usboarder == 3 :
            
            # IF statement if randomized number is in run list
            if usboarder_chance in run :
                print("""
You have SUCCESSFULLY crossed the US boarder.
    
    DORA: Wow that was tiring! Let's now head to the US Black Market!""")
                input(prompt = """PRESS ENTER TO CONTINUE!""")
                stage4()
                break
            
            # ELSE statement if randomized number is not in run list
            else :
                print("""
You died! The patrol officers saw you and started shooting at you!""")
                
                # Quit or Reset Syntax
                stage3_2_fail = input(prompt = """
    ENTER:
        1 to RESTART STAGE 3
        2 to QUIT GAME
        """)
                if stage3_2_fail == "1" :
                    stage3()
                    break
                elif stage3_2_fail == "2":
                    fail()
                    break
                else :
                    print("Invalid input! Restarting game!")
                    intro()
                    break
        
        else :
            print("""
    DORA: That's not part of the choices!""")
       
# STAGE 4: Selling the baby winky to the black market
def stage4() :
    
    
    print("""
    
####       ##      ## ##   #### ##  
 ##         ##    ##   ##  # ## ##  
 ##       ## ##   ####       ##     
 ##       ##  ##   #####     ##     
 ##       ## ###      ###    ##     
 ##  ##   ##  ##  ##   ##    ##     
### ###  ###  ##   ## ##    ####    
                                    
 ## ##   #### ##    ##      ## ##   ### ###  
##   ##  # ## ##     ##    ##   ##   ##  ##  
####       ##      ## ##   ##        ##      
 #####     ##      ##  ##  ##  ###   ## ##   
    ###    ##      ## ###  ##   ##   ##      
##   ##    ##      ##  ##  ##   ##   ##  ##  
 ## ##    ####    ###  ##   ## ##   ### ###    
                                                               
""")
    
    input(prompt = """PRESS ENTER TO CONTINUE!""")
    
    print("""
You arrived safely at the US Black Market.
    
    BOOTS: Woooow! The US Black Market is so nice!
    DORA: Yeah! Now let us sell the Baby Winky that we caught!""")
    
    input(prompt = """PRESS ENTER TO CONTINUE!""")
    
    # WHILE STATEMENT for selling price input
    while True :
        selling_price = input("""
    BUYER: Are you selling that Baby Winky?
    DORA: Si! Are you interested in buying this?
    BUYER: Yes! How much are you willing to sell it?
    
    NOTE: Dora owes the Mexican Cartel 500000 USD.
    PLAYER (Enter an anmount without ","): """).strip()
        
        # TRY EXCEPT to limit answers to integers
        try:
            selling_price = int(selling_price)
        except:
            input(prompt = "I need a number in digits. Press enter to try again.\n")
            continue
        
        # Anything above 800,000 is rejected by buyer
        if selling_price <= 800000 :
            
            # If selling price is equal to 500,000. Trigger win1 function
            if selling_price == 500000 :
                print(f"""
    BUYER: Sure I will buy it for {selling_price} USD!""")
                input(prompt = """<Press ENTER to exit>""")  
                win1()
                break
            
            # If selling price is more than 500,000. Trigger win2 function
            elif selling_price > 500000 :
                print(f"""
    BUYER: Sure I will buy it for {selling_price} USD!""")
                input(prompt = """<Press ENTER to exit>""")  
                win2()
                break
            
            # If selling price is less than 500,000. Player loses
            else :
                print(f"""
    BUYER: Sure I will buy it for {selling_price} USD!
    """)
                print(f"""
    DORA: You sold the Baby Winky so low and I still owe the Mexican Cartel
        {500000 - selling_price} USD""")
                
                # Quit or Reset Syntax
                stage4_fail = input(prompt = """
    ENTER:
        1 to RESTART LAST STAGE
        2 to QUIT GAME
        """)
                if stage4_fail == "1" :
                    stage4()
                    break
                elif stage4_fail == "2":
                    fail()
                    break
                else :
                    print("Invalid input! Restarting game!")
                    intro()
                    break






    
    
#Defining FAIL function
def fail() :
    print("""
 @@@@@                                        @@@@@
@@@@@@@                                      @@@@@@@
@@@@@@@           @@@@@@@@@@@@@@@            @@@@@@@
 @@@@@@@@       @@@@@@@@@@@@@@@@@@@        @@@@@@@@
     @@@@@     @@@@@@@@@@@@@@@@@@@@@     @@@@@
       @@@@@  @@@@@@@@@@@@@@@@@@@@@@@  @@@@@
         @@  @@@@@@@@@@@@@@@@@@@@@@@@@  @@
            @@@@@@@    @@@@@@    @@@@@@
            @@@@@@      @@@@      @@@@@
            @@@@@@      @@@@      @@@@@
             @@@@@@    @@@@@@    @@@@@
              @@@@@@@@@@@  @@@@@@@@@@
               @@@@@@@@@@  @@@@@@@@@
           @@   @@@@@@@@@@@@@@@@@   @@
           @@@@  @@@@ @ @ @ @ @@@@  @@@@
          @@@@@   @@@ @ @ @ @ @@@   @@@@@
        @@@@@      @@@@@@@@@@@@@      @@@@@
      @@@@          @@@@@@@@@@@          @@@@
   @@@@@              @@@@@@@              @@@@@
  @@@@@@@                                 @@@@@@@
   @@@@@                                   @@@@@    
    
    
    """)
    print("""
    You've failed to help Dora, but thanks for playing!""")
    input(prompt = """<Press ENTER to exit>""")

#Defining WIN function for selling at 500000
def win1() :
    print("""
 ## ##    ## ##    ## ##   ### ##   
##   ##  ##   ##  ##   ##   ##  ##  
##       ##   ##  ##   ##   ##  ##  
##  ###  ##   ##  ##   ##   ##  ##  
##   ##  ##   ##  ##   ##   ##  ##  
##   ##  ##   ##  ##   ##   ##  ##  
 ## ##    ## ##    ## ##   ### ##   
                                    
   ####   ## ##   ### ##   
    ##   ##   ##   ##  ##  
    ##   ##   ##   ##  ##  
    ##   ##   ##   ## ##   
##  ##   ##   ##   ##  ##  
##  ##   ##   ##   ##  ##  
 ## #     ## ##   ### ##   

    DORA: Thank you so much for the help! I wished I could have had proffited
        from that but I'm happy I was able to pay my debt! See you again soon!
""")
    input(prompt = """<Press ENTER to exit>""")

#Defining WIN function for selling more than 500000
def win2() :
    print("""
### ###  ##  ##    ## ##   ### ###  ####     ####     ### ###  ###  ##  #### ##  
 ##  ##  ### ##   ##   ##   ##  ##   ##       ##       ##  ##    ## ##  # ## ##  
 ##       ###     ##        ##       ##       ##       ##       # ## #    ##     
 ## ##     ###    ##        ## ##    ##       ##       ## ##    ## ##     ##     
 ##         ###   ##        ##       ##       ##       ##       ##  ##    ##     
 ##  ##  ##  ###  ##   ##   ##  ##   ##  ##   ##  ##   ##  ##   ##  ##    ##     
### ###  ##   ##   ## ##   ### ###  ### ###  ### ###  ### ###  ###  ##   ####    
                                                                            
    DORA: Thank you so much for the help! I'm so happy that I was able to pay
        what I owe to the Mexican cartel but at the same time, I have extra
        money to go on a vacation. Thank you!
""")
    input(prompt = """<Press ENTER to exit>""")            
            
intro()
